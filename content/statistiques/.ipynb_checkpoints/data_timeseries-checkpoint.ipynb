# %% [markdown]
# source   https://fred.stlouisfed.org/series/DCOILBRENTEU/downloaddata

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
import os
datafiles = os.listdir('./data')

datafiles = [ './data/' + name for name in datafiles ]
print datafiles
# Out:
# ['./data/ICNSA.csv', './data/Tfrigo.csv', './data/JTSQUL.csv', './data/DCOILBRENTEU.csv', './data/PLAMBUSDM.csv', './data/PRS30006013.csv', './data/TTLCONS.csv']

# %%
def readXY( filename ):
    data = np.loadtxt(filename, dtype='str', comments='#', delimiter=',',  skiprows=1)

    Y = np.array( [ float(u[1]) for u in data ])
    X = np.array( range(len(Y)) )
    
    return X, Y

# %%
for fname in datafiles:
    X, Y = readXY( fname )
    
    print fname
    plt.figure(figsize=(12, 4)  )
    plt.plot( X, Y,  'k-', alpha=0.5 );
    plt.title( fname )
# Out:
# ./data/ICNSA.csv
# ./data/Tfrigo.csv
# ./data/JTSQUL.csv
# ./data/DCOILBRENTEU.csv
# ./data/PLAMBUSDM.csv
# ./data/PRS30006013.csv
# ./data/TTLCONS.csv

# %% [markdown]
# ## Save to a file

# %%
# Save

data = {}
for fname in datafiles:
    X, Y = readXY( fname )
    
    print fname, len(Y)
    data[fname] = (X, Y)
    
np.save('./timeseriesdata.npy', data)
# Out:
# ./data/ICNSA.csv 2619
# ./data/Tfrigo.csv
#  9585
# ./data/JTSQUL.csv 193
# ./data/DCOILBRENTEU.csv 1553
# ./data/PLAMBUSDM.csv 446
# ./data/PRS30006013.csv 120
# ./data/TTLCONS.csv 288

# %%
# Read
data = np.load('./timeseriesdata.npy').item()

print data.keys()
# Out:
# ['./data/TTLCONS.csv', './data/DCOILBRENTEU.csv', './data/PLAMBUSDM.csv', './data/ICNSA.csv', './data/Tfrigo.csv', './data/JTSQUL.csv', './data/PRS30006013.csv']

# %% [markdown]
# ## Brouillon

# %%
#import datetime
#sDate = '2014-05-06'
#dtDate = datetime.datetime.strptime(sDate,"%m-%d-%Y")

def txt2float( s ):
    if s == '.':
        return 0.0
    else:
        return float(s)

# src  https://fred.stlouisfed.org/series/DCOILBRENTEU/downloaddata
fname = 'data/DCOILBRENTEU.csv'

# https://fred.stlouisfed.org/series/JTSQUL
#fname = 'data/JTSQUL.csv'

#https://fred.stlouisfed.org/series/PRS30006013#0
#fname = 'data/PRS30006013.csv'

# https://fred.stlouisfed.org/series/TTLCONS
#fname = 'data/TTLCONS.csv'


https://fred.stlouisfed.org/series/ICNSA
    
#converters = { 1:float}
data = np.loadtxt(fname, dtype='str', comments='#', delimiter=',',  skiprows=1)

Y = np.array( [ float(u[1]) for u in data ])
X = np.array( range(len(Y)) )

plt.figure(figsize=(12, 4)  )
plt.plot( X, Y,  'k-', alpha=0.5 );
