# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font', size=12)
plt.rc('axes', labelsize=12)

import pandas as pd

# %% [markdown]
# Appliances energy prediction Data Set
# https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction

# %%
df = pd.read_csv('./energydata_complete.csv')

# %%
df.count()
# Out:
# date           19735
# Appliances     19735
# lights         19735
# T1             19735
# RH_1           19735
# T2             19735
# RH_2           19735
# T3             19735
# RH_3           19735
# T4             19735
# RH_4           19735
# T5             19735
# RH_5           19735
# T6             19735
# RH_6           19735
# T7             19735
# RH_7           19735
# T8             19735
# RH_8           19735
# T9             19735
# RH_9           19735
# T_out          19735
# Press_mm_hg    19735
# RH_out         19735
# Windspeed      19735
# Visibility     19735
# Tdewpoint      19735
# rv1            19735
# rv2            19735
# dtype: int64

# %%
df['Appliances'].plot()

# %%
plt.plot( df['T4'], ',')

# %%
plt.plot( df['T_out'], ',')

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
N_train = 200

# %%
dfX = df[:N_train].copy()
dfX = dfX.drop(['date', 'Appliances', 'lights'], axis=1)

# %%
dfY = df['Appliances'][:N_train]

# %%
reg.fit(dfX.as_matrix(), dfY.as_matrix())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([  36.4011875 ,   -7.43062495,  -86.44697833,  -50.30695483,
#         -78.37776568,  -15.98399492,  -47.78596644,   82.26924588,
#         127.05645746,   -3.40538385,  -60.80162067,   -6.47687308,
#         -25.60052936,   66.0808686 , -126.84059267,  -39.742095  ,
#         293.51246748,  -42.53518474,  248.00421785,   19.25243177,
#          35.34924269,    9.33864641,    1.59374896, -158.85628639,
#          -0.32542542,   -0.32542542])

# %%
plt.plot(reg.coef_)

# %%
plt.plot( dfY )
